# %% [markdown]
# # conditional statements in python
# 1.`python` have four types of conditional statements
# 2. `if` statement
# 3. `eluf` statement
# 4. `else` statement
# 5. `nested` statement
# ```python syntax - if
# if (condition) # if condition is true then execute or run statements inside if block
#     statement1
#     statement2...
# ```
#
# ```python -if, esle
# if (condition):
#     statement1
#     statement2...
# else:
#     statement1
#     statement2...
# ```
#
# ```python -if, elif, else
# if (condition1):
#     statement1...n
# elif(condition2):
#     statement1...n
# elif(condition3):
#     statements1...n
# else(condition3):
#     statements1...n

# %%
# write a program to find the given number is odd?
number = int(input ("please enter number here:"))
if(number%2==1):
    print(number,"is odd number")

# %%
write a program to find the given number is even or odd?
num= int(input("please enter number here:"))
if(num%2==0):
    print(num,"is even number")
else:
    print(num,"is odd number")
# Out:
# Object `odd` not found.
# please enter number here: 123
# 123 is odd number

# %%
# write a program to find the given number is positive or negitive or zero?
n=int(input("please enter number here:"))
if(n>0):
    print(n,"is positive number ")
elif(n>0):
    print(n,"is negitive number")
else:
    print(n,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
"""
write a program to find the grades based on marks
1. if marks in between 80-100 - grade is A
2. if marks in between 60-79 - grade is B
3. if marks in between 40-59 - grade is C 
4. if marks in between 25-39 - grade is D
5. if marks in between 0-24 - grade is Fall 
6. if marks other than above output is - please enter correct marks 
"""
marks=int(input("please enter student marks here:"))
if(marks>=80 and marks<=100):
    print(marks, "grade is A")
elif (marks>=60 and marks <=79):
    print(marks,"grade is B")
elif (marks>=40 and marks<=59):
    print(marks,"grade is C")
elif (marks>=25 and marks<=39):
    print(marks,"grade is D")
else:
    print("please enter correct marks")
# Out:
# please enter student marks here: 66
# 66 grade is B

# %%
# write a program to find the largest number from three number?
m1=int(input(" enter frist  number here:"))
m2=int(input(" enter sencond number here:"))
m3=int(input(" enter third number here:"))
if(m1>=m2 and m1>=m3):
    print(m1,"is largest number")
elif(m2>=m3 and m2>=m1):
    print(m2,"is largest number")
else:
    print(m3,"is largest number")
# Out:
#  enter frist  number here: 55
#  enter sencond number here: 77
#  enter third number here: 99
# 99 is largest number

# %%
# write a program to validate login credentials using conditional statements?
username=str(input("please enter username here:"))
if(username=="tia@123"):
    print("username is valid")
    password=str(input("please enter user password here :"))
if(password=="TIA@12345"):
    print("user detlails are seccussfully validated,thankyou")
elif username != correct_username and password == correct_password:
    print("Invalid username!")
elif username == correct_username and password != correct_password:
    print("Invalid password!")
else:
    print("Invalid username and password!")
# Out:
# please enter username here: tia@123
# username is valid
# please enter user password here : TIA@12345
# user detlails are seccussfully validated,thankyou

# %%
"""
wirte a program to find the even number with number of digits
1. if number in between 1 to 9 then output is - 1 digit even number 
2. if number in between 10 to 99 then output is - 2 digit even number 
3. if number in between 100 to 999 then output is - 3 digit even number 
4. if number in between 1000 to 9999 then output is - 4 digit even number 
5. if other then above range then is - weired even number 
"""
number=int(input("please enter number here:"))
if (num%2 == 0):
    if (num>=1 and num<=9):
        print("1 digit even number")
    elif (num>=10 and num<=99):
        print("2 digit even number")
    elif (num>=100 and num<=999):
        print("3 digit even number")
    elif (num>=10000 and num<=9999):
        print("4 digit even number")
    else:
        print("weird even number")
else:
    print("Not an even number")
# Out:
# please enter number here: 5559
# Not an even number

# %%
"""
write a program to find the boy or girl with the names
1. the name with end 'i','a','u' its describes girl 
2. the name with end other letter its describes boy 
"""
name=int(input("please enter the name here:"))

if(name=="end with 'a'"):
    print("boy or girl")
elif(name=="end with 'u'"):
    print("boy or girl")
elif(name=="end with 'i'"):
    print("boy or girl")
elif(name=="end with other letters"):
    print("boy or girl")
else:
    print("boy or gril")
